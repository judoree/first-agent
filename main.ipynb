# %%
import openai

client = openai.OpenAI()
messages = []

# %%
def get_weather(city):
    return "33 degrees celcius."


FUNCTION_MAP = {"get_weather": get_weather}

# %%
TOOLS = [
    {
        "type": "function",
        "function": {
            "name": "get_weather",
            "description": "A function to get the weather of a city.",
            "parameters": {
                "type": "object",
                "properties": {
                    "city": {
                        "type": "string",
                        "description": "The name of the city to get the weather of.",
                    }
                },
                "required": ["city"],
            },
        },
    }
]

# %%
def call_ai():
    response = client.chat.completions.create(
        model="gpt-5-nano",
        messages=messages,
        tools=TOOLS,
    )
    print(response)
    message = response.choices[0].message.content
    messages.append({"role": "assistant", "content": message})
    print(f"AI: {message}")

# %%
while True:
    message = input("Send a message to the LLM...")
    if message == "quit" or message == "q":
        break
    else:
        messages.append({"role": "user", "content": message})
        print(f"User: {message}")
        call_ai()
# Out:
# User: 안녕 나는 김주현이야
# ChatCompletion(id='chatcmpl-D8i7vizVtALsgSvq93z8TIMm8d0Qx', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='반가워요, 주현님! 무엇을 도와드릴까요? 날씨 확인이나 간단한 번역, 글쓰기 아이디어, 일정 관리 등 어떤 게 필요하신지 말씀해 주세요. 특정 도시의 날씨를 알고 싶으시면 도시 이름만 알려주셔도 됩니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1770968619, model='gpt-5-nano-2025-08-07', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=713, prompt_tokens=148, total_tokens=861, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=640, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# AI: 반가워요, 주현님! 무엇을 도와드릴까요? 날씨 확인이나 간단한 번역, 글쓰기 아이디어, 일정 관리 등 어떤 게 필요하신지 말씀해 주세요. 특정 도시의 날씨를 알고 싶으시면 도시 이름만 알려주셔도 됩니다.
# User: 스페인 날씨는 어때?
# ChatCompletion(id='chatcmpl-D8i8D3teIPTqyHNySRl8iNobqn71l', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='스페인은 지역마다 날씨가 크게 다릅니다. 간단히 요약하면:\n\n- 북부(갈리시아, 바스크 등): 비가 자주 오고 흐린 날이 많음.\n- 중앙 고원(마드리드 등): 여름은 매우 덥고 겨울은 춥다.\n- 지중해 해안(바르셀로나, 발렌시아 등): 겨울은 온화하고 여름은 더움.\n- 남부(세비야, 말라가 등): 여름이 매우 덥고 겨울은 비교적 온화함.\n- 카나리아 제도: 연중 온화하고 비가 적다.\n\n원하시면 특정 도시의 현재 날씨를 바로 확인해 드릴 수 있어요. 어떤 도시의 날씨를 알고 싶으신가요? 예: 마드리드, 바르셀로나, 발렌시아, 세비야 등 혹은 여러 도시를 한 번에 보고 싶으신가요?', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1770968637, model='gpt-5-nano-2025-08-07', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=1373, prompt_tokens=231, total_tokens=1604, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=1152, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# AI: 스페인은 지역마다 날씨가 크게 다릅니다. 간단히 요약하면:
#
# - 북부(갈리시아, 바스크 등): 비가 자주 오고 흐린 날이 많음.
# - 중앙 고원(마드리드 등): 여름은 매우 덥고 겨울은 춥다.
# - 지중해 해안(바르셀로나, 발렌시아 등): 겨울은 온화하고 여름은 더움.
# - 남부(세비야, 말라가 등): 여름이 매우 덥고 겨울은 비교적 온화함.
# - 카나리아 제도: 연중 온화하고 비가 적다.
#
# 원하시면 특정 도시의 현재 날씨를 바로 확인해 드릴 수 있어요. 어떤 도시의 날씨를 알고 싶으신가요? 예: 마드리드, 바르셀로나, 발렌시아, 세비야 등 혹은 여러 도시를 한 번에 보고 싶으신가요?
